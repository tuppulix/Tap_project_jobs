# %%
import pandas as pd 
import re

def salary_median(string):
    match = re.search(r'\$(\d+K)-\$(\d+K)', string)
    if match:
        lower_salary = int(match.group(1).replace('K', '')) * 1000
        upper_salary = int(match.group(2).replace('K', '')) * 1000
        median_salary = (lower_salary + upper_salary) / 2
        return median_salary
    else:
        return None
    
def experience_median(string):
    match = re.search(r'(\d+)\s+to\s+(\d+)\s+Years', string)
    if match:
        lower_experience = int(match.group(1))
        upper_experience = int(match.group(2))
        median_experience = (lower_experience + upper_experience) / 2
        return median_experience
    else:
        return None

dataset = pd.read_csv("archive/job_descriptions.csv")
dataset["Salary Range"] = dataset["Salary Range"].apply(lambda x: salary_median(x))
dataset["Experience"] = dataset["Experience"].apply(lambda x: experience_median(x))
dataset = dataset.drop(columns=["Contact","Contact Person"])
print(dataset.head(20))
print(len(dataset))

dataset.to_csv("archive/job_descriptions2.csv")
# Out:
#               Job Id  Experience Qualifications  Salary Range  \
# 0   1089843540111562        10.0         M.Tech       79000.0
# 1    398454096642776         7.0            BCA       86000.0
# 2    481640072963533         6.0            PhD       82500.0
# 3    688192671473044         7.5            PhD       78000.0
# 4    117057806156508         6.5            MBA       75500.0
# 5    116831420231957         8.0            MCA       76000.0
# 6   1292168246729889         9.0            PhD       83000.0
# 7   1498778686197107         5.0          M.Com       83500.0
# 8   1680293940995740         5.5            BBA       83500.0
# 9    255627812588102         5.5            BBA       70000.0
# 10  2696958764033354         6.5            BCA       80500.0
# 11  1446194141960546         8.0         B.Tech       81000.0
# 12  1914121205954296         9.0            MCA       93500.0
# 13   290761760113904         4.5          B.Com       71000.0
# 14  1627539131873813         5.0            MCA       77500.0
# 15  2691974960988857         8.0          M.Com       82500.0
# 16  2823887164112482         9.5         M.Tech       71500.0
# 17    76902098772934         5.5             BA       86000.0
# 18   235216486127884         7.5             BA       88000.0
# 19   407980927519454         7.0            PhD       96500.0
#
#                 location                       Country  latitude  longitude  \
# 0                Douglas                   Isle of Man   54.2361    -4.5481
# 1               Ashgabat                  Turkmenistan   38.9697    59.5563
# 2                  Macao              Macao SAR, China   22.1987   113.5439
# 3             Porto-Novo                         Benin    9.3077     2.3158
# 4               Santiago                         Chile  -35.6751   -71.5429
# 5               Brussels                       Belgium   50.5039     4.4699
# 6            George Town                Cayman Islands   19.3133   -81.2546
# 7             Ṣo Tom̩         Sao Tome and Principe    0.1864     6.6131
# 8                   Male                      Maldives    3.2028    73.2207
# 9           Saint John's           Antigua and Barbuda   17.0608   -61.7964
# 10                Manama                       Bahrain   26.0667    50.5577
# 11  The City of Hamilton                       Bermuda   32.3078   -64.7505
# 12              Kingston                       Jamaica   18.1096   -77.2975
# 13                Banjul                        Gambia   13.4432   -15.3101
# 14              Damascus          Syrian Arab Republic   34.8021    38.9968
# 15                 Sanaa                         Yemen   15.5527    48.5164
# 16            San Marino                    San Marino   43.9424    12.4578
# 17               Papeete              French Polynesia  -17.6797  -149.4068
# 18                 Seoul                   North Korea   40.3399   127.5101
# 19              Kinshasa  Democratic Republic Of Congo   -4.0383    21.7587
#
#     Work Type  Company Size  ... Preference                     Job Title  \
# 0      Intern         26801  ...     Female  Digital Marketing Specialist
# 1      Intern        100340  ...     Female                 Web Developer
# 2   Temporary         84525  ...       Male            Operations Manager
# 3   Full-Time        129896  ...     Female              Network Engineer
# 4      Intern         53944  ...     Female                 Event Manager
# 5   Full-Time         23196  ...       Male               Software Tester
# 6   Temporary         26119  ...       Both                       Teacher
# 7    Contract         40558  ...     Female                UX/UI Designer
# 8   Temporary        105343  ...     Female                UX/UI Designer
# 9   Full-Time        102069  ...       Both               Wedding Planner
# 10   Contract        130338  ...     Female                    QA Analyst
# 11   Contract        117285  ...       Male           Litigation Attorney
# 12  Part-Time         79071  ...       Both           Mechanical Engineer
# 13  Temporary        127900  ...     Female         Network Administrator
# 14  Full-Time         92128  ...       Male               Account Manager
# 15  Part-Time         92028  ...       Male                 Brand Manager
# 16  Part-Time         49100  ...       Male                 Social Worker
# 17  Full-Time         29318  ...       Male      Social Media Coordinator
# 18   Contract        126630  ...     Female    Email Marketing Specialist
# 19  Temporary         48199  ...     Female                 HR Generalist
#
#                               Role           Job Portal  \
# 0             Social Media Manager             Snagajob
# 1           Frontend Web Developer             Idealist
# 2          Quality Control Manager         Jobs2Careers
# 3        Wireless Network Engineer             FlexJobs
# 4               Conference Manager         Jobs2Careers
# 5        Quality Assurance Analyst             Snagajob
# 6                Classroom Teacher             FlexJobs
# 7          User Interface Designer               Indeed
# 8             Interaction Designer               Indeed
# 9               Wedding Consultant  Stack Overflow Jobs
# 10  Performance Testing Specialist            Glassdoor
# 11             Family Law Attorney  Stack Overflow Jobs
# 12      Mechanical Design Engineer  Stack Overflow Jobs
# 13        Network Security Analyst             FlexJobs
# 14           Sales Account Manager              USAJOBS
# 15           Product Brand Manager          SimplyHired
# 16            School Social Worker            Glassdoor
# 17                 Content Creator         Jobs2Careers
# 18          Deliverability Analyst      Internships.com
# 19                  HR Coordinator             Snagajob
#
#                                       Job Description  \
# 0   Social Media Managers oversee an organizations...
# 1   Frontend Web Developers design and implement u...
# 2   Quality Control Managers establish and enforce...
# 3   Wireless Network Engineers design, implement, ...
# 4   A Conference Manager coordinates and manages c...
# 5   A Quality Assurance Analyst tests software and...
# 6   A Classroom Teacher educates students in a spe...
# 7   User Interface Designers focus on the visual a...
# 8   Interaction Designers specialize in designing ...
# 9   A Wedding Consultant assists couples in planni...
# 10  Performance Testing Specialists assess the per...
# 11  Family Law Attorneys deal with legal matters r...
# 12  Mechanical Design Engineers create and develop...
# 13  Protect an organizations computer networks and...
# 14  A Sales Account Manager is responsible for bui...
# 15  A Product Brand Manager focuses on promoting a...
# 16  Support students social and emotional well-bei...
# 17  Create engaging and relevant content, such as ...
# 18  Monitor and improve email deliverability rates...
# 19  HR Coordinators assist in HR functions such as...
#
#                                              Benefits  \
# 0   {'Flexible Spending Accounts (FSAs), Relocatio...
# 1   {'Health Insurance, Retirement Plans, Paid Tim...
# 2   {'Legal Assistance, Bonuses and Incentive Prog...
# 3   {'Transportation Benefits, Professional Develo...
# 4   {'Flexible Spending Accounts (FSAs), Relocatio...
# 5   {'Life and Disability Insurance, Stock Options...
# 6   {'Flexible Spending Accounts (FSAs), Relocatio...
# 7   {'Employee Assistance Programs (EAP), Tuition ...
# 8   {'Transportation Benefits, Professional Develo...
# 9   {'Legal Assistance, Bonuses and Incentive Prog...
# 10  {'Flexible Spending Accounts (FSAs), Relocatio...
# 11  {'Employee Referral Programs, Financial Counse...
# 12  {'Tuition Reimbursement, Stock Options or Equi...
# 13  {'Legal Assistance, Bonuses and Incentive Prog...
# 14  {'Casual Dress Code, Social and Recreational A...
# 15  {'Health Insurance, Retirement Plans, Flexible...
# 16  {'Health Insurance, Retirement Plans, Flexible...
# 17  {'Casual Dress Code, Social and Recreational A...
# 18  {'Employee Referral Programs, Financial Counse...
# 19  {'Health Insurance, Retirement Plans, Flexible...
#
#                                                skills  \
# 0   Social media platforms (e.g., Facebook, Twitte...
# 1   HTML, CSS, JavaScript Frontend frameworks (e.g...
# 2   Quality control processes and methodologies St...
# 3   Wireless network design and architecture Wi-Fi...
# 4   Event planning Conference logistics Budget man...
# 5   Quality assurance processes Testing methodolog...
# 6   Teaching pedagogy Classroom management Curricu...
# 7   UI design principles and best practices Graphi...
# 8   Interaction design principles User behavior an...
# 9   Wedding planning Vendor coordination Event man...
# 10  Performance testing Load testing Stress testin...
# 11  Family law Divorce proceedings Child custody M...
# 12  Mechanical engineering CAD software (e.g., Sol...
# 13  Network security protocols Intrusion detection...
# 14  Account management Sales strategy Negotiation ...
# 15  Product branding and marketing Product lifecyc...
# 16  School social work principles Student assessme...
# 17  Content creation (e.g., writing, editing, grap...
# 18  Email deliverability best practices Spam filte...
# 19  Human resources Recruitment Employee onboardin...
#
#                                      Responsibilities  \
# 0   Manage and grow social media accounts, create ...
# 1   Design and code user interfaces for websites, ...
# 2   Establish and enforce quality control standard...
# 3   Design, configure, and optimize wireless netwo...
# 4   Specialize in conference and convention planni...
# 5   Test software applications and systems to iden...
# 6   Plan and deliver engaging lessons, adapting te...
# 7   Create visually appealing user interfaces (UI)...
# 8   Work on interaction design, defining how users...
# 9   Offer expert advice and guidance to couples pl...
# 10  Focus on performance and load testing to asses...
# 11  Specialize in family law matters, such as divo...
# 12  Design mechanical systems, components, and pro...
# 13  Manage and secure computer networks, including...
# 14  Manage sales accounts and ensure revenue growt...
# 15  Manage the branding of specific products or pr...
# 16  Collaborate with schools to support students a...
# 17  Create compelling and shareable content for so...
# 18  Focus on email deliverability, monitoring emai...
# 19  Assist with recruitment activities, including ...
#
#                                   Company  \
# 0                       Icahn Enterprises
# 1            PNC Financial Services Group
# 2        United Services Automobile Assn.
# 3                                    Hess
# 4                            Cairn Energy
# 5   Adani Ports and Special Economic Zone
# 6                                   FedEx
# 7                            Ryder System
# 8           Zee Entertainment Enterprises
# 9                                     CSX
# 10                             McDonald's
# 11                            TPG Telecom
# 12                        ThyssenKrupp AG
# 13                       EnLink Midstream
# 14                    NGL Energy Partners
# 15                               Bayer AG
# 16                                  Deere
# 17                 Mondelez International
# 18                                     3M
# 19                                    KKR
#
#                                       Company Profile
# 0   {"Sector":"Diversified","Industry":"Diversifie...
# 1   {"Sector":"Financial Services","Industry":"Com...
# 2   {"Sector":"Insurance","Industry":"Insurance: P...
# 3   {"Sector":"Energy","Industry":"Mining, Crude-O...
# 4   {"Sector":"Energy","Industry":"Energy - Oil & ...
# 5   {"Sector":"Infrastructure","Industry":"Ports a...
# 6   {"Sector":"Logistics","Industry":"Mail, Packag...
# 7   {"Sector":"Transportation","Industry":"Transpo...
# 8   {"Sector":"Media & Entertainment","Industry":"...
# 9   {"Sector":"Transportation","Industry":"Railroa...
# 10  {"Sector":"Food and Beverage","Industry":"Food...
# 11  {"Sector":"Telecommunications","Industry":"Tel...
# 12  {"Sector":"Manufacturing","Industry":"Industri...
# 13  {"Sector":"Energy","Industry":"Pipelines","Cit...
# 14  {"Sector":"Energy","Industry":"Pipelines","Cit...
# 15  {"Sector":"Pharmaceuticals","Industry":"Pharma...
# 16  {"Sector":"Industrial","Industry":"Constructio...
# 17  {"Sector":"Food and Beverage","Industry":"Food...
# 18  {"Sector":"Conglomerate","Industry":"Chemicals...
# 19  {"Sector":"Financials","Industry":"Securities"...
#
# [20 rows x 21 columns]
# 1615940

# %%
import pandas as pd 
import re

dataset = pd.read_csv("archive/job_descriptions2.csv")
dataset3 = dataset.sample(300000)
dataset = dataset.drop(dataset3.index)
print(len(dataset))
print(len(dataset3))
dataset3.to_csv("archive/job_descriptions_subset.csv", index=False)
dataset.to_csv("archive/job_descriptions2.csv", index=False)
# Out:
# 1315940
# 300000
